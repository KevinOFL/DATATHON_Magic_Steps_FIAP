# %% [markdown]
# # Analise exploratoria dos dados do DATASET PEDE 2024

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds_pede_2022 = pd.read_excel('app/data/base_de_dados_pede_2024.xlsx', sheet_name='PEDE2022')
ds_pede_2023 = pd.read_excel('app/data/base_de_dados_pede_2024.xlsx', sheet_name='PEDE2023')
ds_pede_2024 = pd.read_excel('app/data/base_de_dados_pede_2024.xlsx', sheet_name='PEDE2024')

# %%
ds_pede_2022.head(5)
# Out:
#      RA  Fase Turma     Nome  Ano nasc  Idade 22  Gênero  Ano ingresso  \
# 0  RA-1     7     A  Aluno-1      2003        19  Menina          2016
# 1  RA-2     7     A  Aluno-2      2005        17  Menina          2017
# 2  RA-3     7     A  Aluno-3      2005        17  Menina          2016
# 3  RA-4     7     A  Aluno-4      2005        17  Menino          2017
# 4  RA-5     7     A  Aluno-5      2005        17  Menina          2016
#
#   Instituição de ensino  Pedra 20  ... Inglês Indicado  Atingiu PV    IPV  \
# 0        Escola Pública  Ametista  ...    6.0      Sim         Não  7.278
# 1          Rede Decisão  Ametista  ...    9.7      Não         Não  6.778
# 2          Rede Decisão  Ametista  ...    6.9      Não         Não  7.556
# 3          Rede Decisão  Ametista  ...    8.7      Não         Não  5.278
# 4          Rede Decisão  Ametista  ...    5.7      Não         Não  7.389
#
#     IAN               Fase ideal  Defas  \
# 0   5.0  Fase 8 (Universitários)     -1
# 1  10.0           Fase 7 (3º EM)      0
# 2  10.0           Fase 7 (3º EM)      0
# 3  10.0           Fase 7 (3º EM)      0
# 4  10.0           Fase 7 (3º EM)      0
#
#                                         Destaque IEG  \
# 0  Melhorar: Melhorar a sua entrega de lições de ...
# 1  Melhorar: Melhorar a sua entrega de lições de ...
# 2    Destaque: A sua boa entrega das lições de casa.
# 3  Melhorar: Melhorar a sua entrega de lições de ...
# 4    Destaque: A sua boa entrega das lições de casa.
#
#                                         Destaque IDA  \
# 0  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 1  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 2  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 3  Melhorar: Empenhar-se mais nas aulas e avaliaç...
# 4  Melhorar: Empenhar-se mais nas aulas e avaliaç...
#
#                                         Destaque IPV
# 0  Melhorar: Integrar-se mais aos Princípios Pass...
# 1  Melhorar: Integrar-se mais aos Princípios Pass...
# 2  Destaque: A sua boa integração aos Princípios ...
# 3  Melhorar: Integrar-se mais aos Princípios Pass...
# 4  Melhorar: Integrar-se mais aos Princípios Pass...
#
# [5 rows x 42 columns]

# %%
ds_pede_2023.head(20)
# Out:
#          RA    Fase  INDE 2023 Pedra 2023           Turma Nome Anonimizado  \
# 0      RA-1  FASE 8        NaN        NaN              8E          Aluno-1
# 1   RA-1000    ALFA   7.916200   Ametista  ALFA U - G2/G3       Aluno-1000
# 2   RA-1001    ALFA   8.116200    Topázio  ALFA U - G2/G3       Aluno-1001
# 3   RA-1002    ALFA   7.901200   Ametista  ALFA U - G2/G3       Aluno-1002
# 4   RA-1003    ALFA   7.652200   Ametista  ALFA V - G0/G1       Aluno-1003
# 5   RA-1004    ALFA   8.313700    Topázio  ALFA V - G0/G1       Aluno-1004
# 6   RA-1005    ALFA   8.425200    Topázio  ALFA V - G0/G1       Aluno-1005
# 7   RA-1006    ALFA   8.592200    Topázio  ALFA V - G0/G1       Aluno-1006
# 8   RA-1007    ALFA   8.078200    Topázio  ALFA V - G0/G1       Aluno-1007
# 9   RA-1008    ALFA   8.135950    Topázio  ALFA V - G0/G1       Aluno-1008
# 10  RA-1009    ALFA   7.245000   Ametista  ALFA Y - G0/G1       Aluno-1009
# 11  RA-1010    ALFA   8.706450    Topázio  ALFA Y - G0/G1       Aluno-1010
# 12  RA-1011    ALFA   7.330950   Ametista  ALFA Y - G0/G1       Aluno-1011
# 13  RA-1012    ALFA   7.964950   Ametista  ALFA Y - G0/G1       Aluno-1012
# 14  RA-1013    ALFA   7.623700   Ametista  ALFA Y - G0/G1       Aluno-1013
# 15  RA-1014    ALFA   8.258200    Topázio  ALFA Y - G0/G1       Aluno-1014
# 16  RA-1015  FASE 1   7.538908   Ametista              1A       Aluno-1015
# 17  RA-1016  FASE 1   7.762575   Ametista              1A       Aluno-1016
# 18  RA-1017  FASE 1   6.505333      Agata              1A       Aluno-1017
# 19  RA-1018  FASE 1   6.824000      Agata              1A       Aluno-1018
#
#            Data de Nasc                Idade     Gênero  Ano ingresso  ...  \
# 0   2003-03-10 00:00:00  1900-01-20 00:00:00   Feminino          2016  ...
# 1             4/20/2015                    8   Feminino          2023  ...
# 2             3/13/2014                    9   Feminino          2023  ...
# 3             7/13/2014                    9   Feminino          2023  ...
# 4             1/22/2015                    8  Masculino          2023  ...
# 5            12/29/2014                    8   Feminino          2023  ...
# 6             7/16/2015                    8  Masculino          2023  ...
# 7             5/24/2015                    8   Feminino          2023  ...
# 8   2015-06-01 00:00:00  1900-01-08 00:00:00  Masculino          2023  ...
# 9             5/22/2015                    8  Masculino          2023  ...
# 10            3/27/2015                    8  Masculino          2023  ...
# 11            1/14/2015                    8  Masculino          2023  ...
# 12  2015-03-11 00:00:00  1900-01-07 00:00:00  Masculino          2023  ...
# 13            5/18/2015                    8   Feminino          2023  ...
# 14           12/25/2015                    7  Masculino          2023  ...
# 15  2016-05-02 00:00:00  1900-01-07 00:00:00   Feminino          2023  ...
# 16            6/24/2013                   10   Feminino          2023  ...
# 17            3/14/2013                   10   Feminino          2023  ...
# 18  2012-01-10 00:00:00  1900-01-11 00:00:00  Masculino          2023  ...
# 19  2013-10-12 00:00:00  1900-01-09 00:00:00  Masculino          2023  ...
#
#    Indicado Atingiu PV       IPV   IAN               Fase Ideal  Defasagem  \
# 0       NaN        NaN       NaN  10.0  Fase 8 (Universitários)          0
# 1       NaN        NaN  8.920000  10.0       ALFA (1° e 2° ano)          0
# 2       NaN        NaN  9.170000   5.0     Fase 1 (3° e 4° ano)         -1
# 3       NaN        NaN  8.920000   5.0     Fase 1 (3° e 4° ano)         -1
# 4       NaN        NaN  8.750000  10.0       ALFA (1° e 2° ano)          0
# 5       NaN        NaN  7.420000  10.0       ALFA (1° e 2° ano)          0
# 6       NaN        NaN  8.165000  10.0       ALFA (1° e 2° ano)          0
# 7       NaN        NaN  8.000000  10.0       ALFA (1° e 2° ano)          0
# 8       NaN        NaN  7.680000  10.0       ALFA (1° e 2° ano)          0
# 9       NaN        NaN  7.500000  10.0       ALFA (1° e 2° ano)          0
# 10      NaN        NaN  7.840000  10.0       ALFA (1° e 2° ano)          0
# 11      NaN        NaN  8.590000  10.0       ALFA (1° e 2° ano)          0
# 12      NaN        NaN  7.675000  10.0       ALFA (1° e 2° ano)          0
# 13      NaN        NaN  7.845000  10.0       ALFA (1° e 2° ano)          0
# 14      NaN        NaN  5.760000  10.0       ALFA (1° e 2° ano)          0
# 15      NaN        NaN  8.255000  10.0       ALFA (1° e 2° ano)          0
# 16      NaN        NaN  7.786667   5.0     Fase 2 (5° e 6° ano)         -1
# 17      NaN        NaN  7.730000   5.0     Fase 2 (5° e 6° ano)         -1
# 18      NaN        NaN  8.116667   5.0     Fase 2 (5° e 6° ano)         -1
# 19      NaN        NaN  8.060000  10.0     Fase 1 (3° e 4° ano)          0
#
#     Destaque IEG  Destaque IDA  Destaque IPV  Destaque IPV.1
# 0            NaN           NaN           NaN             NaN
# 1            NaN           NaN           NaN             NaN
# 2            NaN           NaN           NaN             NaN
# 3            NaN           NaN           NaN             NaN
# 4            NaN           NaN           NaN             NaN
# 5            NaN           NaN           NaN             NaN
# 6            NaN           NaN           NaN             NaN
# 7            NaN           NaN           NaN             NaN
# 8            NaN           NaN           NaN             NaN
# 9            NaN           NaN           NaN             NaN
# 10           NaN           NaN           NaN             NaN
# 11           NaN           NaN           NaN             NaN
# 12           NaN           NaN           NaN             NaN
# 13           NaN           NaN           NaN             NaN
# 14           NaN           NaN           NaN             NaN
# 15           NaN           NaN           NaN             NaN
# 16           NaN           NaN           NaN             NaN
# 17           NaN           NaN           NaN             NaN
# 18           NaN           NaN           NaN             NaN
# 19           NaN           NaN           NaN             NaN
#
# [20 rows x 48 columns]

# %%
ds_pede_2024.head(5)
# Out:
#         RA  Fase INDE 2024 Pedra 2024           Turma Nome Anonimizado  \
# 0     RA-1    8E       NaN        NaN              8E          Aluno-1
# 1  RA-1000    1N  8.364791    Topázio              1N       Aluno-1000
# 2  RA-1001    1N  7.796432   Ametista              1N       Aluno-1001
# 3  RA-1002  ALFA  7.967867   Ametista  ALFA N - G2/G3       Aluno-1002
# 4  RA-1003  ALFA  7.627589   Ametista  ALFA J - G2/G3       Aluno-1003
#
#   Data de Nasc  Idade     Gênero  Ano ingresso  ...    IPV   IAN  \
# 0   2003-10-03     21   Feminino          2021  ...    NaN  10.0
# 1   2015-04-20      9   Feminino          2023  ...  7.835  10.0
# 2   2014-03-13     10   Feminino          2023  ...  7.920   5.0
# 3   2014-07-13     10   Feminino          2023  ...  8.250   5.0
# 4   2015-01-22      9  Masculino          2023  ...  7.500   5.0
#
#                 Fase Ideal Defasagem Destaque IEG  Destaque IDA  Destaque IPV  \
# 0  Fase 8 (Universitários)         0          NaN           NaN           NaN
# 1     Fase 1 (3° e 4° ano)         0          NaN           NaN           NaN
# 2     Fase 2 (5° e 6° ano)        -1          NaN           NaN           NaN
# 3     Fase 1 (3° e 4° ano)        -1          NaN           NaN           NaN
# 4     Fase 1 (3° e 4° ano)        -1          NaN           NaN           NaN
#
#                                       Escola  Ativo/ Inativo  Ativo/ Inativo.1
# 0           Universidade Santo Amaro (UNISA)        Cursando          Cursando
# 1            EE Helio Luiz Dobrochinski Prof        Cursando          Cursando
# 2            EE Helio Luiz Dobrochinski Prof        Cursando          Cursando
# 3  EM Cecilia Cristina de Oliveira Rodrigues        Cursando          Cursando
# 4         EM Maria Ignez Concelles Irma Ines        Cursando          Cursando
#
# [5 rows x 50 columns]

# %%
ds_pede_2022.columns = ds_pede_2022.columns.str.strip()
ds_pede_2023.columns = ds_pede_2023.columns.str.strip()
ds_pede_2024.columns = ds_pede_2024.columns.str.strip()

# %%
ds_pede_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 860 entries, 0 to 859
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     860 non-null    object
#  1   Fase                   860 non-null    int64
#  2   Turma                  860 non-null    object
#  3   Nome                   860 non-null    object
#  4   Ano nasc               860 non-null    int64
#  5   Idade 22               860 non-null    int64
#  6   Gênero                 860 non-null    object
#  7   Ano ingresso           860 non-null    int64
#  8   Instituição de ensino  860 non-null    object
#  9   Pedra 20               323 non-null    object
#  10  Pedra 21               462 non-null    object
#  11  Pedra 22               860 non-null    object
#  12  INDE 22                860 non-null    float64
#  13  Cg                     860 non-null    int64
#  14  Cf                     860 non-null    int64
#  15  Ct                     860 non-null    int64
#  16  Nº Av                  860 non-null    int64
#  17  Avaliador1             860 non-null    object
#  18  Rec Av1                860 non-null    object
#  19  Avaliador2             860 non-null    object
#  20  Rec Av2                860 non-null    object
#  21  Avaliador3             534 non-null    object
#  22  Rec Av3                860 non-null    object
#  23  Avaliador4             310 non-null    object
#  24  Rec Av4                296 non-null    object
#  25  IAA                    860 non-null    float64
#  26  IEG                    860 non-null    float64
#  27  IPS                    860 non-null    float64
#  28  Rec Psicologia         860 non-null    object
#  29  IDA                    860 non-null    float64
#  30  Matem                  858 non-null    float64
#  31  Portug                 858 non-null    float64
#  32  Inglês                 283 non-null    float64
#  33  Indicado               860 non-null    object
#  34  Atingiu PV             860 non-null    object
#  35  IPV                    860 non-null    float64
#  36  IAN                    860 non-null    float64
#  37  Fase ideal             860 non-null    object
#  38  Defas                  860 non-null    int64
#  39  Destaque IEG           860 non-null    object
#  40  Destaque IDA           860 non-null    object
#  41  Destaque IPV           860 non-null    object
# dtypes: float64(10), int64(9), object(23)
# memory usage: 282.3+ KB

# %%
ds_pede_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     1014 non-null   object
#  1   Fase                   1014 non-null   object
#  2   INDE 2023              931 non-null    float64
#  3   Pedra 2023             931 non-null    object
#  4   Turma                  1014 non-null   object
#  5   Nome Anonimizado       1014 non-null   object
#  6   Data de Nasc           1014 non-null   object
#  7   Idade                  1014 non-null   object
#  8   Gênero                 1014 non-null   object
#  9   Ano ingresso           1014 non-null   int64
#  10  Instituição de ensino  1014 non-null   object
#  11  Pedra 20               240 non-null    object
#  12  Pedra 21               335 non-null    object
#  13  Pedra 22               600 non-null    object
#  14  Pedra 23               0 non-null      float64
#  15  INDE 22                600 non-null    float64
#  16  INDE 23                0 non-null      float64
#  17  Cg                     0 non-null      float64
#  18  Cf                     0 non-null      float64
#  19  Ct                     0 non-null      float64
#  20  Nº Av                  938 non-null    float64
#  21  Avaliador1             938 non-null    object
#  22  Rec Av1                0 non-null      float64
#  23  Avaliador2             938 non-null    object
#  24  Rec Av2                0 non-null      float64
#  25  Avaliador3             707 non-null    object
#  26  Rec Av3                0 non-null      float64
#  27  Avaliador4             334 non-null    object
#  28  Rec Av4                0 non-null      float64
#  29  IAA                    951 non-null    float64
#  30  IEG                    938 non-null    float64
#  31  IPS                    945 non-null    float64
#  32  IPP                    938 non-null    float64
#  33  Rec Psicologia         0 non-null      float64
#  34  IDA                    937 non-null    float64
#  35  Mat                    937 non-null    float64
#  36  Por                    937 non-null    float64
#  37  Ing                    334 non-null    float64
#  38  Indicado               0 non-null      float64
#  39  Atingiu PV             0 non-null      float64
#  40  IPV                    938 non-null    float64
#  41  IAN                    1014 non-null   float64
#  42  Fase Ideal             1014 non-null   object
#  43  Defasagem              1014 non-null   int64
#  44  Destaque IEG           0 non-null      float64
#  45  Destaque IDA           0 non-null      float64
#  46  Destaque IPV           0 non-null      float64
#  47  Destaque IPV.1         0 non-null      float64
# dtypes: float64(29), int64(2), object(17)
# memory usage: 380.4+ KB

# %%
ds_pede_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 50 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RA                     1156 non-null   object
#  1   Fase                   1156 non-null   object
#  2   INDE 2024              1092 non-null   object
#  3   Pedra 2024             1092 non-null   object
#  4   Turma                  1156 non-null   object
#  5   Nome Anonimizado       1156 non-null   object
#  6   Data de Nasc           1156 non-null   datetime64[ns]
#  7   Idade                  1156 non-null   int64
#  8   Gênero                 1156 non-null   object
#  9   Ano ingresso           1156 non-null   int64
#  10  Instituição de ensino  1155 non-null   object
#  11  Pedra 20               191 non-null    object
#  12  Pedra 21               264 non-null    object
#  13  Pedra 22               472 non-null    object
#  14  Pedra 23               690 non-null    object
#  15  INDE 22                472 non-null    float64
#  16  INDE 23                690 non-null    float64
#  17  Cg                     0 non-null      float64
#  18  Cf                     0 non-null      float64
#  19  Ct                     0 non-null      float64
#  20  Nº Av                  1156 non-null   int64
#  21  Avaliador1             1029 non-null   object
#  22  Rec Av1                0 non-null      float64
#  23  Avaliador2             1029 non-null   object
#  24  Rec Av2                0 non-null      float64
#  25  Avaliador3             793 non-null    object
#  26  Avaliador4             407 non-null    object
#  27  Avaliador5             148 non-null    object
#  28  Avaliador6             6 non-null      object
#  29  IAA                    1054 non-null   float64
#  30  IEG                    1156 non-null   float64
#  31  IPS                    1054 non-null   float64
#  32  IPP                    1054 non-null   float64
#  33  Rec Psicologia         0 non-null      float64
#  34  IDA                    1055 non-null   float64
#  35  Mat                    1051 non-null   float64
#  36  Por                    1050 non-null   float64
#  37  Ing                    474 non-null    float64
#  38  Indicado               0 non-null      float64
#  39  Atingiu PV             0 non-null      float64
#  40  IPV                    1054 non-null   float64
#  41  IAN                    1156 non-null   float64
#  42  Fase Ideal             1156 non-null   object
#  43  Defasagem              1156 non-null   int64
#  44  Destaque IEG           0 non-null      float64
#  45  Destaque IDA           0 non-null      float64
#  46  Destaque IPV           0 non-null      float64
#  47  Escola                 1155 non-null   object
#  48  Ativo/ Inativo         1156 non-null   object
#  49  Ativo/ Inativo.1       1156 non-null   object
# dtypes: datetime64[ns](1), float64(23), int64(4), object(22)
# memory usage: 451.7+ KB

# %% [markdown]
# ## Funções reutilizaveis

# %% [markdown]
# * Função de plotagem de gráfico de barras com diferencial entre notas dos evadidos que estão acima de mediana geral no indice e abaixo com visualização da quantidade.

# %%
# Plota um gráfico de barras para a coluna desejada de um DataFrame
def plot_grafico_barras_indices_evadidos(df, indice_coluna, mediana_geral, titulo_grafico, xlabel, ylabel, figsize=(9, 12)):
    # Lógica para definir as cores das barras com base na média
    ordem_notas = df[indice_coluna].value_counts().index

    cores = ['#4CAF50' if nota >= mediana_geral else '#F44336' for nota in ordem_notas]

    plt.figure(figsize=figsize)

    ax = sns.countplot(
        data=df,
        y=indice_coluna,
        order=ordem_notas,
        palette=cores
    )

    for container in ax.containers:
        labels = [f"{int(valor)}" if valor > 0 else "" for valor in container.datavalues]
        ax.bar_label(container, labels=labels, label_type='edge', padding=3, fontsize=10)
        
    max_count = df[indice_coluna].value_counts().max()
    plt.xlim(0, max_count * 1.1)
    plt.title(titulo_grafico)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    plt.xticks(rotation=0)
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# * Função que retorna a porcentagem de alunos que estão abaixo e acima da mediana geral

# %%
def porcentagem_acima_e_abaixo_da_mediana(df, indice_coluna, mediana_geral):
    cont = len(df)
    
    if cont == 0:
        return 0.0, 0.0
    
    acima_da_mediana = df[df[indice_coluna] >= mediana_geral]
    abaixo_da_mediana = df[df[indice_coluna] < mediana_geral]

    porcentagem_acima = (len(acima_da_mediana) / cont) * 100
    porcentagem_abaixo = (len(abaixo_da_mediana) / cont) * 100

    return porcentagem_acima, porcentagem_abaixo

# %% [markdown]
# * Função que gera a mediana de uma coluna especifica de um dataframe

# %%
def mediana_indice(df, indice_coluna):
    return df[indice_coluna].median()

# %% [markdown]
# * Função que efetua o print de estátisticas de todos os evadidos

# %%
def print_estatisticas_evadidos_geral(df_geral, df_alvo, indice_coluna, ano_referencia):
    mediana_geral = df_geral[indice_coluna].median()
    mediana_alvo = df_alvo[indice_coluna].median()
    porcentagem_acima, porcentagem_abaixo = porcentagem_acima_e_abaixo_da_mediana(df_alvo, indice_coluna, mediana_geral)
    
    print(f"Mediana geral de {indice_coluna} para {ano_referencia} dos RAs que permaneceram: {mediana_geral}")
    print(f"Mediana de {indice_coluna} para RAs presentes em {ano_referencia} mas não em {ano_referencia+1}: {mediana_alvo}")
    print(f"Porcentagem de RAs acima da mediana: {porcentagem_acima:.1f}%")
    print(f"Porcentagem de RAs abaixo da mediana: {porcentagem_abaixo:.1f}%")

# %% [markdown]
# * Função que efetua o print de estátisticas de todos os evadidos por gênero

# %%
def print_estatisticas_evadidos_por_genero(df_geral, df_alvo, indice_coluna, ano_referencia):
    mediana_geral = df_geral[indice_coluna].median()
    if ano_referencia == 2022:
        df_fem = df_alvo[df_alvo['Gênero'] == 'Menina'].copy()
        df_mac = df_alvo[df_alvo['Gênero'] == 'Menino'].copy()
        porcentagem_abaixo_fem, porcentagem_acima_fem = porcentagem_acima_e_abaixo_da_mediana(df_fem, indice_coluna, mediana_geral)
        porcentagem_abaixo_mac, porcentagem_acima_mac = porcentagem_acima_e_abaixo_da_mediana(df_mac, indice_coluna, mediana_geral)
        print(f"Quantidade total de RAs feminino que evadiram: {len(df_fem)}")
        print(f"Quantidade total de RAs masculino que evadiram: {len(df_mac)}")
        print(f"Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: {porcentagem_acima_fem:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: {porcentagem_abaixo_fem:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: {porcentagem_acima_mac:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: {porcentagem_abaixo_mac:.1f}%")
    elif ano_referencia == 2023:
        df_fem = df_alvo[df_alvo['Gênero'] == 'Feminino'].copy()
        df_mac = df_alvo[df_alvo['Gênero'] == 'Masculino'].copy()
        porcentagem_abaixo_fem, porcentagem_acima_fem = porcentagem_acima_e_abaixo_da_mediana(df_fem, indice_coluna, mediana_geral)
        porcentagem_abaixo_mac, porcentagem_acima_mac = porcentagem_acima_e_abaixo_da_mediana(df_mac, indice_coluna, mediana_geral)
        print(f"Quantidade total de RAs feminino que evadiram: {len(df_fem)}")
        print(f"Quantidade total de RAs masculino que evadiram: {len(df_mac)}")
        print(f"Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: {porcentagem_acima_fem:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: {porcentagem_abaixo_fem:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: {porcentagem_acima_mac:.1f}%")
        print(f"Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: {porcentagem_abaixo_mac:.1f}%")

# %% [markdown]
# ## Análise tChurn

# %%
ras_2022 = set(ds_pede_2022['RA'])
ras_2023 = set(ds_pede_2023['RA'])
ras_2024 = set(ds_pede_2024['RA'])

# %%
ras_que_ficaram_2022 = ras_2022 & ras_2023
ras_que_ficaram_2023 = ras_2023 & ras_2024
ras_que_sairam_2022 = ras_2022 - ras_2023
ras_que_sairam_2023 = ras_2023 - ras_2024

df_permaneceram_2022 = ds_pede_2022[ds_pede_2022['RA'].isin(ras_que_ficaram_2022)].copy()
df_permaneceram_2023 = ds_pede_2023[ds_pede_2023['RA'].isin(ras_que_ficaram_2023)].copy()
df_fem_permaneceram_2022 = df_permaneceram_2022[df_permaneceram_2022['Gênero'] == 'Menina'].copy()
df_fem_permaneceram_2023 = df_permaneceram_2023[df_permaneceram_2023['Gênero'] == 'Feminino'].copy()
df_masc_permaneceram_2022 = df_permaneceram_2022[df_permaneceram_2022['Gênero'] == 'Menino'].copy()
df_masc_permaneceram_2023 = df_permaneceram_2023[df_permaneceram_2023['Gênero'] == 'Masculino'].copy()

df_evadiram_2022 = ds_pede_2022[ds_pede_2022['RA'].isin(ras_que_sairam_2022)].copy()
df_evadiram_2023 = ds_pede_2023[ds_pede_2023['RA'].isin(ras_que_sairam_2023)].copy()
df_fem_evadiram_2022 = df_evadiram_2022[df_evadiram_2022['Gênero'] == 'Menina'].copy()
df_fem_evadiram_2023 = df_evadiram_2023[df_evadiram_2023['Gênero'] == 'Feminino'].copy()
df_masc_evadiram_2022 = df_evadiram_2022[df_evadiram_2022['Gênero'] == 'Menino'].copy()
df_masc_evadiram_2023 = df_evadiram_2023[df_evadiram_2023['Gênero'] == 'Masculino'].copy()

# %%
print(f"Quantidade total de RAs em 2022: {len(ras_2022)}")
print(f"Quantidade total que evadiram em 2022: {len(df_evadiram_2022)}")
print(f"Quantidade total de RAs feminino que evadiram em 2022: {len(df_fem_evadiram_2022)}")
print(f"Quantidade total de RAs masculino que evadiram em 2022: {len(df_masc_evadiram_2022)}")
print(f"Quantidade total que permaneceram em 2022: {len(df_permaneceram_2022)}")
print(f"Quantidade total de RA feminino que permaneceram em 2022: {len(df_fem_permaneceram_2022)}")
print(f"Quantidade total de RA masculino que permaneceram em 2022: {len(df_masc_permaneceram_2022)}")
print("--"*50)
print(f"Quantidade total de RAs em 2023: {len(ras_2023)}")
print(f"Quantidade total que evadiram em 2023: {len(df_evadiram_2023)}")
print(f"Quantidade total de RAs feminino que evadiram em 2023: {len(df_fem_evadiram_2023)}")
print(f"Quantidade total de RAs masculino que evadiram em 2023: {len(df_masc_evadiram_2023)}")
print(f"Quantidade total que permaneceram em 2023: {len(df_permaneceram_2023)}")
print(f"Quantidade total de RA feminino que permaneceram em 2023: {len(df_fem_permaneceram_2023)}")
print(f"Quantidade total de RA masculino que permaneceram em 2023: {len(df_masc_permaneceram_2023)}")
# Out:
# Quantidade total de RAs em 2022: 860
# Quantidade total que evadiram em 2022: 260
# Quantidade total de RAs feminino que evadiram em 2022: 144
# Quantidade total de RAs masculino que evadiram em 2022: 116
# Quantidade total que permaneceram em 2022: 600
# Quantidade total de RA feminino que permaneceram em 2022: 313
# Quantidade total de RA masculino que permaneceram em 2022: 287
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs em 2023: 1014
# Quantidade total que evadiram em 2023: 249
# Quantidade total de RAs feminino que evadiram em 2023: 131
# Quantidade total de RAs masculino que evadiram em 2023: 118
# Quantidade total que permaneceram em 2023: 765
# Quantidade total de RA feminino que permaneceram em 2023: 415
# Quantidade total de RA masculino que permaneceram em 2023: 350

# %% [markdown]
# ### Analisando o indice IEG dos alunos que evadiram

# %% [markdown]
# * Analisando o IEG dos alunos que estavam em 2022 mas não estão em 2023

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'IEG', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'IEG', 2022)
# Out:
# Mediana geral de IEG para 2022 dos RAs que permaneceram: 8.6
# Mediana de IEG para RAs presentes em 2022 mas não em 2023: 7.2
# Porcentagem de RAs acima da mediana: 23.1%
# Porcentagem de RAs abaixo da mediana: 76.9%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 71.5%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 28.5%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 83.6%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 16.4%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'IEG',
    mediana_indice(df_permaneceram_2022, 'IEG'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IEG em 2022',
    'Quantidade de RAs Evadidos',
    'IEG'
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# * Analisando o IEG dos alunos que estavam em 2023 mas não estão em 2024

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2023, df_evadiram_2023, 'IEG', 2023)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2023, df_evadiram_2023, 'IEG', 2023)
# Out:
# Mediana geral de IEG para 2023 dos RAs que permaneceram: 9.1
# Mediana de IEG para RAs presentes em 2023 mas não em 2024: 8.5
# Porcentagem de RAs acima da mediana: 27.7%
# Porcentagem de RAs abaixo da mediana: 70.7%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 131
# Quantidade total de RAs masculino que evadiram: 118
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 70.2%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 27.5%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 71.2%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 28.0%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2023,
    'IEG',
    mediana_indice(df_permaneceram_2023, 'IEG'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IEG em 2023',
    'Quantidade de RAs Evadidos',
    'IEG'
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice IDA dos alunos que evadiram

# %% [markdown]
# * Analisando o IDA dos alunos que estavam em 2022 mas não estão em 2023

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'IDA', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'IDA', 2022)
# Out:
# Mediana geral de IDA para 2022 dos RAs que permaneceram: 6.8
# Mediana de IDA para RAs presentes em 2022 mas não em 2023: 5.35
# Porcentagem de RAs acima da mediana: 25.0%
# Porcentagem de RAs abaixo da mediana: 75.0%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 69.4%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 30.6%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 81.9%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 18.1%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'IDA',
    mediana_indice(df_permaneceram_2022, 'IDA'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IDA em 2022',
    'Quantidade de RAs Evadidos',
    'IDA'
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# * Analisando o IDA dos alunos que estavam em 2023 mas não estão em 2024

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2023, df_evadiram_2023, 'IDA', 2023)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2023, df_evadiram_2023, 'IDA', 2023)
# Out:
# Mediana geral de IDA para 2023 dos RAs que permaneceram: 6.9
# Mediana de IDA para RAs presentes em 2023 mas não em 2024: 6.3
# Porcentagem de RAs acima da mediana: 38.2%
# Porcentagem de RAs abaixo da mediana: 59.8%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 131
# Quantidade total de RAs masculino que evadiram: 118
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 58.8%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 38.2%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 61.0%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 38.1%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2023,
    'IDA',
    mediana_indice(df_permaneceram_2023, 'IDA'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IDA em 2023',
    'Quantidade de RAs Evadidos',
    'IDA'
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice IPV dos alunos que evadiram

# %% [markdown]
# * Analisando o IPV dos alunos que estavam em 2022 mas não estão em 2023

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'IPV', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'IPV', 2022)
# Out:
# Mediana geral de IPV para 2022 dos RAs que permaneceram: 7.5
# Mediana de IPV para RAs presentes em 2022 mas não em 2023: 6.9305
# Porcentagem de RAs acima da mediana: 29.6%
# Porcentagem de RAs abaixo da mediana: 70.4%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 68.1%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 31.9%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 73.3%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 26.7%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'IPV',
    mediana_indice(df_permaneceram_2022, 'IPV'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IPV em 2022',
    'Quantidade de RAs Evadidos',
    'IPV',
    (9, 18)
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# * Analisando o IPV dos alunos que estavam em 2023 mas não estão em 2024

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2023, df_evadiram_2023, 'IPV', 2023)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2023, df_evadiram_2023, 'IPV', 2023)
# Out:
# Mediana geral de IPV para 2023 dos RAs que permaneceram: 8.116666667
# Mediana de IPV para RAs presentes em 2023 mas não em 2024: 7.7525
# Porcentagem de RAs acima da mediana: 36.1%
# Porcentagem de RAs abaixo da mediana: 62.2%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 131
# Quantidade total de RAs masculino que evadiram: 118
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 55.0%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 42.7%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 70.3%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 28.8%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2023,
    'IPV',
    mediana_indice(df_permaneceram_2023, 'IPV'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IPV em 2023',
    'Quantidade de RAs Evadidos',
    'IPV',
    (9, 26)
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice IPS dos alunos que evadiram

# %% [markdown]
# * Analisando o IPS dos alunos que estavam em 2022 mas não estão em 2023

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'IPS', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'IPS', 2022)
# Out:
# Mediana geral de IPS para 2022 dos RAs que permaneceram: 7.5
# Mediana de IPS para RAs presentes em 2022 mas não em 2023: 7.5
# Porcentagem de RAs acima da mediana: 65.8%
# Porcentagem de RAs abaixo da mediana: 34.2%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 37.5%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 62.5%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 30.2%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 69.8%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'IPS',
    mediana_indice(df_permaneceram_2022, 'IPS'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IPS em 2022',
    'Quantidade de RAs Evadidos',
    'IPS',
    (9, 9)
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# * Analisando o IPS dos alunos que estavam em 2023 mas não estão em 2024

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2023, df_evadiram_2023, 'IPS', 2023)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2023, df_evadiram_2023, 'IPS', 2023)
# Out:
# Mediana geral de IPS para 2023 dos RAs que permaneceram: 5.0
# Mediana de IPS para RAs presentes em 2023 mas não em 2024: 5.0
# Porcentagem de RAs acima da mediana: 55.4%
# Porcentagem de RAs abaixo da mediana: 41.8%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 131
# Quantidade total de RAs masculino que evadiram: 118
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 44.3%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 53.4%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 39.0%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 57.6%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2023,
    'IPV',
    mediana_indice(df_permaneceram_2023, 'IPV'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IPV em 2023',
    'Quantidade de RAs Evadidos',
    'IPV',
    (9, 26)
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice IAA dos alunos que evadiram

# %% [markdown]
# * Analisando o IAA dos alunos que estavam em 2022 mas não estão em 2023

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'IAA', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'IAA', 2022)
# Out:
# Mediana geral de IAA para 2022 dos RAs que permaneceram: 9.0
# Mediana de IAA para RAs presentes em 2022 mas não em 2023: 8.5
# Porcentagem de RAs acima da mediana: 39.6%
# Porcentagem de RAs abaixo da mediana: 60.4%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 66.7%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 33.3%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 52.6%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 47.4%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'IAA',
    mediana_indice(df_permaneceram_2022, 'IAA'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IAA em 2022',
    'Quantidade de RAs Evadidos',
    'IAA',
    (9, 9)
)
# Out:
# /tmp/ipykernel_279632/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plot_grafico_barras_indices_evadidos(
#       2     df_evadiram_2022,
#       3     'IAA',
#       4     mediana_indice(df_permaneceram_2022, 'IAA'),
#       5     'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IAA em 2022',
#       6     'Quantidade de RAs Evadidos',
#       7     'IAA',
#       8     (9, 9)
#       9 )
#
# Cell In[10], line 29, in plot_grafico_barras_indices_evadidos(df, indice_coluna, mediana_geral, titulo_grafico, xlabel, ylabel, figsize)
#      27 plt.xticks(rotation=0)
#      28 plt.grid(axis='x', linestyle='--', alpha=0.7)
# ---> 29 plt.tight_layout()
#      30 plt.show()
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/pyplot.py:2843, in tight_layout(pad, h_pad, w_pad, rect)
#    2835 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2836 def tight_layout(
#    2837     *,
#    (...)   2841     rect: tuple[float, float, float, float] | None = None,
#    2842 ) -> None:
# -> 2843     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3638 previous_engine = self.get_layout_engine()
#    3639 self.set_layout_engine(engine)
# -> 3640 engine.execute(self)
#    3641 if previous_engine is not None and not isinstance(
#    3642     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3643 ):
#    3644     _api.warn_external('The figure layout has changed to tight')
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/layout_engine.py:188, in TightLayoutEngine.execute(self, fig)
#     186 renderer = fig._get_renderer()
#     187 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 188     kwargs = get_tight_layout_figure(
#     189         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     190         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     191         rect=info['rect'])
#     192 if kwargs:
#     193     fig.subplots_adjust(**kwargs)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)    280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/axes/_base.py:4587, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4584     bbox_artists = self.get_default_bbox_extra_artists()
#    4586 for a in bbox_artists:
# -> 4587     bbox = a.get_tightbbox(renderer)
#    4588     if (bbox is not None
#    4589             and 0 < bbox.width < np.inf
#    4590             and 0 < bbox.height < np.inf):
#    4591         bb.append(bbox)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/text.py:2030, in Annotation.get_tightbbox(self, renderer)
#    2028 def get_tightbbox(self, renderer=None):
#    2029     # docstring inherited
# -> 2030     if not self._check_xy(renderer):
#    2031         return Bbox.null()
#    2032     return super().get_tightbbox(renderer)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/text.py:1591, in _AnnotationBase._check_xy(self, renderer)
#    1588 if b or (b is None and self.xycoords == "data"):
#    1589     # check if self.xy is inside the Axes.
#    1590     xy_pixel = self._get_position_xy(renderer)
# -> 1591     return self.axes.contains_point(xy_pixel)
#    1592 return True
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/axes/_base.py:4474, in _AxesBase.contains_point(self, point)
#    4469 def contains_point(self, point):
#    4470     """
#    4471     Return whether *point* (pair of pixel coordinates) is inside the Axes
#    4472     patch.
#    4473     """
# -> 4474     return self.patch.contains_point(point, radius=1.0)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/patches.py:238, in Patch.contains_point(self, point, radius)
#     180 """
#     181 Return whether the given point is inside the patch.
#     182
#    (...)    234
#     235 """
#     236 radius = self._process_radius(radius)
#     237 return self.get_path().contains_point(point,
# --> 238                                       self.get_transform(),
#     239                                       radius)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/patches.py:309, in Patch.get_transform(self)
#     307 def get_transform(self):
#     308     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 309     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/transforms.py:1348, in Transform.__add__(self, other)
#    1341 def __add__(self, other):
#    1342     """
#    1343     Compose two transforms together so that *self* is followed by *other*.
#    1344
#    1345     ``A + B`` returns a transform ``C`` so that
#    1346     ``C.transform(x) == B.transform(A.transform(x))``.
#    1347     """
# -> 1348     return (composite_transform_factory(self, other)
#    1349             if isinstance(other, Transform) else
#    1350             NotImplemented)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/transforms.py:2523, in composite_transform_factory(a, b)
#    2521 elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2522     return CompositeAffine2D(a, b)
# -> 2523 return CompositeGenericTransform(a, b)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/transforms.py:2357, in CompositeGenericTransform.__init__(self, a, b, **kwargs)
#    2354 self.input_dims = a.input_dims
#    2355 self.output_dims = b.output_dims
# -> 2357 super().__init__(**kwargs)
#    2358 self._a = a
#    2359 self._b = b
#
# KeyboardInterrupt:

# %% [markdown]
# * Analisando o IAA dos alunos que estavam em 2023 mas não estão em 2024

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2023, df_evadiram_2023, 'IAA', 2023)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2023, df_evadiram_2023, 'IAA', 2023)
# Out:
# Mediana geral de IAA para 2023 dos RAs que permaneceram: 8.5
# Mediana de IAA para RAs presentes em 2023 mas não em 2024: 8.3
# Porcentagem de RAs acima da mediana: 45.4%
# Porcentagem de RAs abaixo da mediana: 53.0%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 131
# Quantidade total de RAs masculino que evadiram: 118
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 57.3%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 40.5%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 48.3%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 50.8%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2023,
    'IAA',
    mediana_indice(df_permaneceram_2023, 'IAA'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice IAA em 2023',
    'Quantidade de RAs Evadidos',
    'IAA',
    (9, 9)
)
# Out:
# /tmp/ipykernel_9/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice INDE dos alunos que evadiram

# %% [markdown]
# * Analisando o INDE dos alunos que estavam em 2022 mas não estão em 2023
# * Não efetuei a analise de 2023 pois pelo o que eu vi a equipe da Passos Mágicos efetua a atualização desses dados no próximo ano e não durante o ano atual da analise.

# %%
print_estatisticas_evadidos_geral(df_permaneceram_2022, df_evadiram_2022, 'INDE 22', 2022)
print("--"*50)
print_estatisticas_evadidos_por_genero(df_permaneceram_2022, df_evadiram_2022, 'INDE 22', 2022)
# Out:
# Mediana geral de INDE 22 para 2022 dos RAs que permaneceram: 7.4025
# Mediana de INDE 22 para RAs presentes em 2022 mas não em 2023: 6.6690000000000005
# Porcentagem de RAs acima da mediana: 23.1%
# Porcentagem de RAs abaixo da mediana: 76.9%
# ----------------------------------------------------------------------------------------------------
# Quantidade total de RAs feminino que evadiram: 144
# Quantidade total de RAs masculino que evadiram: 116
# Porcentagem de RAs que evadiram do gênero Feminino acima da mediana: 70.1%
# Porcentagem de RAs que evadiram do gênero Feminino abaixo da mediana: 29.9%
# Porcentagem de RAs que evadiram do gênero Masculino acima da mediana: 85.3%
# Porcentagem de RAs que evadiram do gênero Masculino abaixo da mediana: 14.7%

# %%
plot_grafico_barras_indices_evadidos(
    df_evadiram_2022,
    'INDE 22',
    mediana_indice(df_permaneceram_2022, 'INDE 22'),
    'Distribuição de RAs evadidos que conseguiram ultrapassar a mediana dos que permaneceram do indice INDE 22 em 2022',
    'Quantidade de RAs Evadidos',
    'INDE 22',
    (9, 38)
)
# Out:
# /tmp/ipykernel_9/3099596338.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(

# %% [markdown]
# ### Analisando o indice INSTITUIÇÃO DE ENSINO dos alunos que evadiram e permaneceram

# %% [markdown]
# * Verificando as IES dos que evadiram e por gênero

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_evadiram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_evadiram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs evadidos por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_fem_evadiram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_fem_evadiram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs femininos evadidos por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_masc_evadiram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_masc_evadiram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs masculinos evadidos por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_evadiram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_evadiram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs evadidos por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_fem_evadiram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_fem_evadiram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs femininos evadidos por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_masc_evadiram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_masc_evadiram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs masculinos evadidos por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Evadidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_permaneceram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_permaneceram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs permaneceram por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Permaneceram')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_fem_permaneceram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_fem_permaneceram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs femininos que permaneceram por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Permanecidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_masc_permaneceram_2022['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_masc_permaneceram_2022,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs masculinos que permaneceram por instituição de ensino em 2022')
plt.xlabel('Quantidade de RAs Permanecidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_permaneceram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_permaneceram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs permaneceram por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Permaneceram')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_fem_permaneceram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_fem_permaneceram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs femininos que permaneceram por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Permanecidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))

ordem_notas = df_masc_permaneceram_2023['Instituição de ensino'].value_counts().index

sns.countplot(
    data=df_masc_permaneceram_2023,
    y='Instituição de ensino',
    order=ordem_notas,
)

plt.title('Distribuição de RAs masculinos que permaneceram por instituição de ensino em 2023')
plt.xlabel('Quantidade de RAs Permanecidos')
plt.ylabel('Instituição de Ensino')

plt.xticks(rotation=0)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
